# %% [markdown]
# 00_config é basicamente um lugar central para criar e manter essas variáveis de configuraç

# %%
# Notebook: 00_config
CATALOG = "credit_lab"
BRONZE = f"{CATALOG}.bronze"
SILVER = f"{CATALOG}.silver"
GOLD = f"{CATALOG}.gold"
MONITORING = f"{CATALOG}.monitoring"

RAW_VOLUME = f"/Volumes/{CATALOG}/bronze/raw_files"

FILES = {
    "application_train": "application_train.csv",
    "bureau": "bureau.csv",
    "previous_application": "previous_application.csv",
    "installments_payments": "installments_payments.csv",
    "credit_card_balance": "credit_card_balance.csv",
}

print("Catálogo:", CATALOG)
print("Volume:", RAW_VOLUME)

# %%
# Confirme que os arquivos existem
import os

for file_name in sorted(os.listdir(RAW_VOLUME)):
    print(file_name)
