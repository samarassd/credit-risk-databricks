# %%
# %sql
SHOW CATALOGS;
SELECT current_catalog() AS catalogo_atual,
       current_schema()  AS schema_atual;

# %%
# %sql
CREATE CATALOG IF NOT EXISTS credit_lab;

CREATE SCHEMA IF NOT EXISTS credit_lab.bronze;
CREATE SCHEMA IF NOT EXISTS credit_lab.silver;
CREATE SCHEMA IF NOT EXISTS credit_lab.gold;
CREATE SCHEMA IF NOT EXISTS credit_lab.monitoring;

CREATE VOLUME IF NOT EXISTS credit_lab.bronze.raw_files
COMMENT 'Arquivos CSV públicos usados no curso de risco de crédito';

# %%
# %python
"#Passo 0.7 - Aprender o ritual de uma sessão no Databricks  [APLICAÇÃO]"

# %% [markdown]
# ###### #Passo 0.7 - Aprender o ritual de uma sessão no Databricks  [APLICAÇÃO]

# %%
# %run ./00_config

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

print("Sessão iniciada")

# %%
print(CATALOG)
print(RAW_VOLUME)
